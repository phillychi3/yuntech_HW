# %%
import numpy as np
import matplotlib.pyplot as plt
from __future__ import division
from sympy import *

# %%
# %matplotlib inline


def f(x):
    return x**2 - np.log(x)


x = np.linspace(-1000, 1000, 201)
y = f(x)
plt.plot(x, y)
# Out:
# C:\Users\phill\AppData\Local\Temp\ipykernel_5156\107571897.py:4: RuntimeWarning: divide by zero encountered in log
#   return x**2-np.log(x)
# C:\Users\phill\AppData\Local\Temp\ipykernel_5156\107571897.py:4: RuntimeWarning: invalid value encountered in log
#   return x**2-np.log(x)

# %%
def f(x):
    return 2 * x - 1 / x


x = np.linspace(-1000, 1000, 201)
y = f(x)
plt.plot(x, y)
# Out:
# C:\Users\phill\AppData\Local\Temp\ipykernel_5156\3576053815.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   return 2*x - 1/x
