# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
def f(x):
    return 1/x

x=np.linspace(-100,100,201)
y=f(x)
plt.plot(x, y)
# Out:
# C:\Users\phill\AppData\Local\Temp\ipykernel_11288\3962888442.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   return 1/x
